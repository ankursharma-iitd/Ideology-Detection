# %%
import spacy
import en_core_web_sm
import pandas as pd
import pickle as pkl
import re
from spacy.pipeline import merge_entities
nlp = en_core_web_sm.load()
nlp.add_pipe(merge_entities)

# %%
base = './dataset/'
my_dataset = base + 'all.txt'
deepak_dataset = base + 'combined-raw-data.csv'

# %%
def process(keywords):
    keywords_hypen = [x.replace(" ", "-") for x in keywords]
    total_keywords = list(set(keywords + keywords_hypen))
    return total_keywords

def is_phrase_in(phrase, text):
    return re.search(r"\b{}(s|es)?\b".format(phrase), text, re.IGNORECASE) is not None

# %%
# Keywords for variouss economic policies
keywords_aadhar = ['Aadhaar', 'UIDAI', 'unique identity number', 'UID', \
                'unique Aadhaar number', 'Unique Identification', \
                'Adhar', 'Aadhar', 'Adhaar', 'Adharcard', 'Aadharcard', \
                'Aadhaarcard', 'Aadhar Card','Aadhar', 'Aadhaar', 'Adhar',\
                'Adharcard', 'Aadharcard', 'Aadhaarcard', 'UIDAI', 'Aadhar Card', \
                '12-digit', 'Enrolment ID', 'Enrollment ID', 'Enrolment Number', \
                'Enrollment Number', 'Personal Identification Number', 'E-Aadhaar', 'UID/EID', \
                'E-Adhar', 'E-Aadhar', 'E-Adhaar', 'Pankaj Kumar', 'uidai.gov.in', \
                'Aadhaar-link', 'Adhaar-link', 'Aadhar-link', 'Adhar-link', \
                'Aadhaar-enable', 'Adhaar-enable', 'Aadhar-enable', 'Adhar-enable'
                ]

keywords_digital_india = ['Digital India', 'Digital Swades', 'india digital', 'digit india', \
                          'digital desh', 'make india', 'digital divide', 'digital payment', 'free wifi service', \
                          'digital locker', 'digital transaction', 'wifi hotspot', 'budget cybersecurity', \
                          'internet connectivity', 'smart city', 'digital business', 'bharatnet project', 
                          'digital present', 'Bharat net', 'digitalised', 'digitalized', 'make in india', \
                         'connectivity', 'digital', 'free wifi']

keywords_cashless = ['cashless', 'digital payment', 'mobikwik','Unified Payment interface','UPI','online transfer',\
                    'SBI pay','ICICI pocket','Payzapp','Paytm','freecharge','ewallet','mobile wallet',\
                     'internet banking','net banking','mobile banking ','PhonePe','physical-POS',\
                     'M-POS','V-POS','digital transaction','pos machine','swipe machine','digital wallet',\
                    'digital economy','card payment','BHIM','banking transaction','swiping machine','payment gateway', \
                    'm pos', 'v pos', 'physical pos']

keywords_egov = ['e-governance', 'information and communication technology', 'e-govt','egovernment',\
                'electronic governance','paperless office','communication','technology','ict academy',\
                 'ict sector','ict information','ict tool','e-district','m-governance', 'e district', \
                'e governance', 'e govt', 'm governance', 'egov', 'e gov', 'information technology', \
                ]

policies = {"aadhar":process(keywords_aadhar), "digital_india":process(keywords_digital_india), "cashless":process(keywords_cashless), "egov":process(keywords_egov)}

# %%
# Keywords for various ICTD policieess
keywords_aadhar = ['Aadhaar', 'UIDAI', 'unique identity number', 'UID', \
            'unique Aadhaar number', 'Unique Identification', \
            'Adhar', 'Aadhar', 'Adhaar', 'Adharcard', 'Aadharcard', \
            'Aadhaarcard', 'Aadhar Card','Aadhar', 'Aadhaar', 'Adhar',\
            'Adharcard', 'Aadharcard', 'Aadhaarcard', 'UIDAI', 'Aadhar Card', \
            '12-digit', 'Enrolment ID', 'Enrollment ID', 'Enrolment Number', \
            'Enrollment Number', 'Personal Identification Number', 'E-Aadhaar', 'UID/EID', \
            'E-Adhar', 'E-Aadhar', 'E-Adhaar', 'Pankaj Kumar', 'uidai.gov.in', \
            'Aadhaar-link', 'Adhaar-link', 'Aadhar-link', 'Adhar-link', \
            'Aadhaar-enable', 'Adhaar-enable', 'Aadhar-enable', 'Adhar-enable'
            ]

keywords_farmers = ['loan waiver', 'loan waivers', 'farmer loan', 'farmer suicide','farmer suicides',\
                    'pest infestation', 'farmer loans','drought','farmer', 'farmers', 'crop insurance',\
                    'Swaminathan Commission', 'National Commission on Farmer', 'kisan', 'agriculture',\
                    'monsoon failure', 'crop failure', 'fertilizers', 'Seeds Corporation', 'crop loss',\
                    'crop losses', 'unseasonal rains', 'irrigation facilities', 'debt traps',\
                   'loan waiver', 'farmer loan', 'farmer suicide', 'pest infestation', 'Swaminathan Commission',\
                    'National Commission on Farmer','kisan', 'monsoon failure', 'crop failure',\
                    'fertilizer', 'Seeds Corporation', 'agricultural', 'crop prices', \
                   'agrarian', 'NCSTC', 'farming community', 'debt waiver', 'waiver scheme', 'farm loan', \
                   'crop loan', 'farmer suicide', 'farmers suicide', 'farmer agitation', 'plight farmer', \
                   'distressed farmer', 'farmer issue', 'farmers\' protest', 'farmer protest', 'agrarian crisis', \
                   'agrarian unrest', 'agriculture protest', 'farmers\' march', 'farmers march', 'farmer march']

keywords_demon = ['Rs 1,000 notes', 'Rs 500 notes', 'lower denomination', 'Rs 500 and Rs 1,000 notes',\
                 'demonetisation', 'denomination note', 'cash withdrawal', 'swipe machine', 'unaccounted money',\
                 'withdrawal limit', 'black money', 'long queue', 'cashless transaction', 'cashless economy',\
                 'demonitis', 'demonitiz', 'swipe machine', 'pos machine', 'fake currency', 'digital payment',\
                 'digital transaction', 'cash transaction', 'cashless economy', 'cash crunch', 'currency switch'\
                 , 'demonetised note', 'cashless transaction', 'note ban', 'currency switch','ATMs', 'now-defunct currency',\
                 'demonitis', 'demonitiz', 'denomination note', 'cash withdrawal', 'swipe machine', 'unaccounted money', 'withdrawal limit', \
                  'pos machine', 'fake currency', 'digital payment', 'digital transaction', 'cash transaction', 'cashless economy',\
                  'black money', 'cash crunch', 'currency switch', 'long queue', 'demonetised note',\
                  'cashless transaction', 'note ban', 'currency switch', 'demonetis', 'demonetiz', 'denomination note']

keywords_gst = ['GST', 'Goods and Services Tax', 'Goods & Services Tax', 'Excise Duty',\
                'good and service tax', 'tax reform', 'goods and services tax', 'gst', 'taxpayers',\
               'GST', 'Goods and Services Tax', 'Goods & Services Tax', 'excise duty', \
               'GSTIN', 'CGST', 'SGST', 'IGST', 'Reverse Charge', 'GSTR', 'GSP', 'Suvidha Provider', \
               'HSN', 'gabbar singh tax', 'goods service tax', 'good service tax']

keywords_tech = ['Privacy', 'Cashless', 'Technology', 'Technological', 'Innovation', 'Software', 'Engineering', 'High Technology',\
            'Technical', 'Tech', 'Personal Data Protection', 'Big Data', 'Artificial Intelligence', 'Digital India', \
                'high speed internet', 'make in india', 'e governance', 'umang', 'digital literacy', 'national policy on electronics', \
                'npe', 'e gadget', 'entrepreneur', 'startup', 'tech', 'scientific', 'science', 'technologies', 'technical', 'cashless', \
                'technology-based', 'smart city']

policies = {"aadhar":process(keywords_aadhar), "demon":process(keywords_demon), "farmers":process(keywords_farmers), "gst":process(keywords_gst), "tech":process(keywords_tech)}

# %% [markdown]
# ### Combine Dataset

# %%
all_sentences = []
with open(my_dataset, 'r') as file:
    for line in file:
        sentence = line.strip().lower()
        if(len(sentence) > 0):
            all_sentences.append(sentence)
print('Num sentences in my dataset: ', len(all_sentences))
# Out:
# Num sentences in my dataset:  49662

# %%
import pandas as pd
df = pd.read_csv(deepak_dataset)
deepak_sentences = list(set(df['statement']))
print('Num sentences in Deepak dataset: ', len(deepak_sentences))
for sentence in deepak_sentences:
    refined_sentence = sentence.strip().lower()
    if(len(refined_sentence) > 0):
        all_sentences.append(refined_sentence)
all_sentences = list(set(all_sentences))
print('Num sentences in final dataset: ', len(all_sentences))
# Out:
# Num sentences in Deepak dataset:  1989
# Num sentences in final dataset:  49921

# %%
output = open(base + 'new-refined-all-by-stmnts.txt','w')
for line in all_sentences:
    output.write(line + '\n')
output.close()

# %% [markdown]
# ### Identify policy

# %%
def check_policy(sent, policies):
    p = []
    words = []
    for policy, keywords in policies.items():
        for word in keywords:
            if is_phrase_in(word, sent):
                words.append(word)
                p.append(policy)
                break
    if len(p)>1:
        print(p)
    return p, words

# %%
output = open(base + 'new-out-all-by-stmnts.txt','w')
with open(base + 'new-refined-all-by-stmnts.txt','r') as file:
    for line in file:
        p, words = check_policy(line, policies)
        p = " ".join(p)
        words = " ".join(words)
        output.write(p+" -- "+words+"\n")
output.close()
# Out:
# ['demon', 'gst']
# ['aadhar', 'tech']
# ['farmers', 'tech']
# ['farmers', 'gst']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['aadhar', 'demon', 'gst', 'tech']
# ['demon', 'tech']
# ['demon', 'gst']
# ['demon', 'tech']
# ['gst', 'tech']
# ['aadhar', 'tech']
# ['demon', 'farmers']
# ['aadhar', 'tech']
# ['aadhar', 'demon']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['demon', 'gst']
# ['farmers', 'gst']
# ['farmers', 'gst']
# ['demon', 'tech']
# ['demon', 'farmers']
# ['demon', 'gst']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['demon', 'gst']
# ['demon', 'farmers']
# ['aadhar', 'tech']
# ['aadhar', 'tech']
# ['demon', 'farmers']
# ['gst', 'tech']
# ['demon', 'tech']
# ['demon', 'gst']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['aadhar', 'tech']
# ['demon', 'gst']
# ['aadhar', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['aadhar', 'demon']
# ['farmers', 'tech']
# ['farmers', 'gst']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['aadhar', 'tech']
# ['demon', 'farmers']
# ['aadhar', 'farmers']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['gst', 'tech']
# ['demon', 'tech']
# ['demon', 'gst']
# ['demon', 'gst']
# ['demon', 'gst']
# ['demon', 'farmers']
# ['demon', 'farmers']
# ['demon', 'tech']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['aadhar', 'tech']
# ['demon', 'gst']
# ['farmers', 'tech']
# ['aadhar', 'tech']
# ['aadhar', 'demon']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'gst']
# ['farmers', 'tech']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['gst', 'tech']
# ['demon', 'tech']
# ['aadhar', 'tech']
# ['aadhar', 'demon']
# ['demon', 'tech']
# ['demon', 'tech']
# ['farmers', 'gst']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['aadhar', 'demon']
# ['farmers', 'tech']
# ['farmers', 'tech']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['demon', 'farmers']
# ['gst', 'tech']
# ['aadhar', 'demon']
# ['aadhar', 'demon', 'gst', 'tech']
# ['demon', 'farmers']
# ['aadhar', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['aadhar', 'gst']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['demon', 'gst']
# ['aadhar', 'tech']
# ['aadhar', 'tech']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'farmers']
# ['aadhar', 'gst', 'tech']
# ['demon', 'gst']
# ['aadhar', 'tech']
# ['demon', 'farmers']
# ['demon', 'tech']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['demon', 'tech']
# ['farmers', 'gst']
# ['demon', 'gst']
# ['aadhar', 'tech']
# ['aadhar', 'tech']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['aadhar', 'farmers']
# ['demon', 'gst']
# ['farmers', 'tech']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'gst']
# ['farmers', 'tech']
# ['farmers', 'tech']
# ['demon', 'farmers']
# ['demon', 'gst']
# ['aadhar', 'tech']
# ['aadhar', 'demon']
# ['demon', 'tech']
# ['demon', 'gst']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['aadhar', 'tech']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['demon', 'tech']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'gst']
# ['demon', 'tech']
# ['aadhar', 'tech']
# ['demon', 'tech']
# ['demon', 'gst']
# ['demon', 'farmers']
# ['farmers', 'tech']
# ['demon', 'farmers']
# ['aadhar', 'farmers']
# ['demon', 'gst']
# ['demon', 'gst']
# ['demon', 'tech']
# ['demon', 'gst']
# ['farmers', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['demon', 'tech']
# ['aadhar', 'farmers']
# ['aadhar', 'gst', 'tech']
# ['aadhar', 'farmers']
# ['demon', 'gst']
# ['gst', 'tech']
# ['demon', 'farmers']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['aadhar', 'tech']
# ['farmers', 'tech']
# ['demon', 'gst']
# ['demon', 'farmers']
# ['demon', 'gst']
# ['aadhar', 'tech']
# ['demon', 'gst']
# ['demon', 'gst']
# ['demon', 'farmers']
# ['demon', 'gst']
# ['demon', 'farmers']
# ['demon', 'tech']
# ['demon', 'tech']
# ['farmers', 'tech']
# ['farmers', 'tech']
# ['demon', 'gst']

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3

# %% [markdown]
# #### Policy filtering for ICTD policies

# %%
aadhar_lines = []
digital_india_lines = []
cashless_lines = []
egov_lines = []
with open(base + "new-refined-all-by-stmnts.txt",'r') as file_s, open(base + "new-out-all-by-stmnts.txt",'r') as file_o: 
    for x, y in zip(file_s, file_o):
        y = y.strip().split(" ")
        if len(y)>1:
            print(y)
        for policy in y:
            if policy=="aadhar":
                aadhar_lines.append(x)
            if policy=="digital_india":
                digital_india_lines.append(x)
            if policy=="cashless":
                cashless_lines.append(x)
            if policy=="egov":
                egov_lines.append(x)
aadhar_lines = list(set(aadhar_lines))
digital_india_lines = list(set(digital_india_lines))
cashless_lines = list(set(cashless_lines))
egov_lines = list(set(egov_lines))
print(len(aadhar_lines), len(digital_india_lines), len(cashless_lines), len(egov_lines))
# Out:
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farming', 'community']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['demon', '--', 'digital', 'payment']
# ['tech', '--', 'startup']
# ['demon', 'gst', '--', 'demonetisation', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'agriculture']
# ['aadhar', '--', 'Unique', 'Identification']
# ['demon', '--', 'cash', 'crunch']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'agrarian', 'crisis']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['aadhar', '--', 'Unique', 'Identification']
# ['tech', '--', 'smart', 'city']
# ['tech', '--', 'Technological']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['aadhar', 'tech', '--', 'UID', 'Technical']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', 'tech', '--', 'agriculture', 'Technology']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'Aadhar']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['tech', '--', 'Engineering']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'technologies']
# ['tech', '--', 'startup']
# ['tech', '--', 'make-in-india']
# ['farmers', '--', 'loan', 'waiver']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'entrepreneur']
# ['aadhar', '--', 'UIDAI']
# ['aadhar', '--', 'Aadhar']
# ['farmers', 'gst', '--', 'agriculture', 'gst']
# ['aadhar', '--', 'Unique', 'Identification']
# ['gst', '--', 'gst']
# ['farmers', '--', 'drought']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Innovation']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'cashless']
# ['farmers', 'tech', '--', 'agriculture', 'Technology']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'crop', 'loss']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', 'gst', '--', 'demonetisation', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'make', 'in', 'india']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'crop', 'loan']
# ['gst', '--', 'tax', 'reform']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technical']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['aadhar', '--', 'UIDAI']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Privacy']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'SGST']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Engineering']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'farming', 'community']
# ['aadhar', '--', 'Aadhar']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farming', 'community']
# ['farmers', '--', 'drought']
# ['gst', '--', 'gst']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'tech']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhar']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'agriculture']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farm', 'loan']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer', 'loan']
# ['demon', '--', 'digital', 'transaction']
# ['tech', '--', 'Engineering']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Technology']
# ['aadhar', '--', 'Aadhaar']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'distressed', 'farmer']
# ['demon', '--', 'denomination', 'note']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'drought']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmer', 'suicides']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agrarian']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['aadhar', 'demon', 'gst', 'tech', '--', 'Aadhaar', 'digital', 'transaction', 'gst', 'Technology']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farm', 'loan']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'cashless']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', 'tech', '--', 'demonetisation', 'cashless']
# ['tech', '--', 'Technical']
# ['tech', '--', 'smart', 'city']
# ['tech', '--', 'e-governance']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['demon', '--', 'digital', 'transaction']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'note', 'ban']
# ['demon', '--', 'ATMs']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhar']
# ['tech', '--', 'science']
# ['farmers', '--', 'loan', 'waiver']
# ['farmers', '--', 'agrarian']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farm', 'loan']
# ['tech', '--', 'science']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'make-in-india']
# ['tech', '--', 'Digital', 'India']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'tech']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['tech', '--', 'entrepreneur']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['aadhar', '--', 'Aadhar']
# ['demon', '--', 'black', 'money']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'farmers', 'suicide']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['aadhar', '--', 'UIDAI']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['demon', '--', 'note', 'ban']
# ['tech', '--', 'science']
# ['gst', '--', 'tax', 'reform']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'e-governance']
# ['farmers', '--', 'loan', 'waiver']
# ['farmers', '--', 'farmers']
# ['demon', 'gst', '--', 'demonetisation', 'Goods', 'and', 'Services', 'Tax']
# ['tech', '--', 'Technology']
# ['demon', 'tech', '--', 'demonetisation', 'Big', 'Data']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['gst', '--', 'excise', 'duty']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'digital', 'payment']
# ['tech', '--', 'make', 'in', 'india']
# ['gst', 'tech', '--', 'gst', 'digital', 'literacy']
# ['gst', '--', 'gst']
# ['aadhar', 'tech', '--', 'UIDAI', 'Software']
# ['tech', '--', 'Innovation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'SGST']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'ATMs']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'make-in-india']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farming', 'community']
# ['farmers', '--', 'kisan']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'science']
# ['demon', '--', 'black', 'money']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'Software']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'tech']
# ['farmers', '--', 'agriculture']
# ['demon', 'farmers', '--', 'demonetisation', 'farmers']
# ['farmers', '--', 'distressed', 'farmer']
# ['demon', '--', 'note', 'ban']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'gst']
# ['tech', '--', 'make', 'in', 'india']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'science']
# ['aadhar', 'tech', '--', 'UIDAI', 'Technology']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'loan', 'waiver']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhaar']
# ['aadhar', 'demon', '--', 'UIDAI', 'digital', 'transaction']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'farm', 'loan']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['demon', '--', 'digital', 'transaction']
# ['tech', '--', 'make-in-india']
# ['farmers', '--', 'drought']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'Reverse', 'Charge']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'tax', 'reform']
# ['farmers', '--', 'farmer']
# ['aadhar', '--', 'Aadhar']
# ['tech', '--', 'Technology']
# ['farmers', 'tech', '--', 'agriculture', 'cashless']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmer']
# ['aadhar', '--', 'UID']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['demon', 'gst', '--', 'demonetisation', 'gabbar', 'singh', 'tax']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Innovation']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'ATMs']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['demon', '--', 'note', 'ban']
# ['gst', '--', 'CGST']
# ['tech', '--', 'technologies']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'Rs', '500', 'notes']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'technologies']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agricultural']
# ['tech', '--', 'Technology']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['farmers', '--', 'waiver', 'scheme']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['aadhar', '--', 'Aadhaar']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['demon', 'gst', '--', 'black', 'money', 'tax', 'reform']
# ['farmers', '--', 'kisan']
# ['tech', '--', 'Technology']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'crop', 'losses']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmer', 'suicides']
# ['tech', '--', 'science']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['tech', '--', 'e-governance']
# ['aadhar', '--', 'Aadhar']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'farmer', 'suicides']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'e-governance']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'science']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'distressed', 'farmer']
# ['farmers', '--', 'farm', 'loan']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['tech', '--', 'Big', 'Data']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'UIDAI']
# ['farmers', 'gst', '--', 'farmers', 'gst']
# ['farmers', 'gst', '--', 'farmers', 'gst']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'drought']
# ['tech', '--', 'Technology']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'waiver', 'scheme']
# ['farmers', '--', 'waiver', 'scheme']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['tech', '--', 'Technology']
# ['tech', '--', 'technologies']
# ['farmers', '--', 'agrarian', 'crisis']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'drought']
# ['demon', '--', 'digital', 'payment']
# ['demon', 'tech', '--', 'demonetisation', 'cashless']
# ['tech', '--', 'entrepreneur']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'cashless']
# ['gst', '--', 'gst']
# ['demon', '--', 'digital', 'transaction']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['demon', 'farmers', '--', 'demonetisation', 'farmers']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'farm', 'loan']
# ['gst', '--', 'gst']
# ['demon', '--', 'note', 'ban']
# ['farmers', '--', 'drought']
# ['demon', '--', 'Rs', '500', 'notes']
# ['farmers', '--', 'kisan']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'crop', 'loan']
# ['gst', '--', 'gst']
# ['demon', '--', 'note', 'ban']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Engineering']
# ['demon', '--', 'note', 'ban']
# ['tech', '--', 'science']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agrarian']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['demon', 'gst', '--', 'demonetisation', 'gst']
# ['demon', '--', 'digital', 'transaction']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'entrepreneur']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'e-governance']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['aadhar', '--', 'Aadhaar']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'cash', 'transaction']
# ['demon', '--', 'note', 'ban']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'note-ban']
# ['demon', '--', 'ATMs']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Engineering']
# ['demon', '--', 'digital', 'payment']
# ['tech', '--', 'science']
# ['farmers', '--', 'loan', 'waiver']
# ['tech', '--', 'Technological']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'agricultural']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technical']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'waiver', 'scheme']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'kisan']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Technical']
# ['tech', '--', 'make', 'in', 'india']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['tech', '--', 'entrepreneur']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'black', 'money']
# ['demon', '--', 'cash', 'transaction']
# ['aadhar', '--', 'UIDAI']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'kisan']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Innovation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['demon', '--', 'ATMs']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['farmers', 'tech', '--', 'agriculture', 'cashless']
# ['farmers', '--', 'farmers']
# ['demon', 'tech', '--', 'cashless', 'transaction', 'cashless']
# ['aadhar', '--', 'UID']
# ['tech', '--', 'make', 'in', 'india']
# ['tech', '--', 'digital', 'literacy']
# ['aadhar', '--', 'Aadhar']
# ['gst', '--', 'gst']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'loan', 'waiver']
# ['gst', '--', 'gst']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', 'tech', '--', 'digital', 'transaction', 'entrepreneur']
# ['farmers', '--', 'crop', 'loan']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'smart', 'city']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers', 'suicide']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Digital', 'India']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'drought']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['aadhar', '--', 'UIDAI']
# ['aadhar', '--', 'UIDAI']
# ['demon', '--', 'Rs', '500', 'notes']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhaar']
# ['demon', 'gst', '--', 'demonetisation', 'Goods', 'and', 'Services', 'Tax']
# ['tech', '--', 'make', 'in', 'india']
# ['gst', '--', 'excise', 'duty']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'loan', 'waiver']
# ['demon', '--', 'ATMs']
# ['farmers', '--', 'drought']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farm', 'loan']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'crop', 'losses']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['farmers', '--', 'crop', 'loan']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'taxpayers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'tech']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farm', 'loan']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', 'farmers', '--', 'note', 'ban', 'farming', 'community']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Innovation']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['farmers', '--', 'agriculture']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'science']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technical']
# ['gst', '--', 'gst']
# ['demon', '--', 'note', 'ban']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Technology']
# ['tech', '--', 'smart', 'city']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'UID']
# ['farmers', '--', 'agricultural']
# ['gst', '--', 'excise', 'duty']
# ['farmers', '--', 'agricultural']
# ['aadhar', 'tech', '--', 'Aadhaar', 'Technology']
# ['tech', '--', 'Engineering']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'gst']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'entrepreneur']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['tech', '--', 'smart', 'city']
# ['farmers', '--', 'kisan']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'ATMs']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'loan', 'waiver']
# ['gst', '--', 'gst']
# ['tech', '--', 'e-governance']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['aadhar', 'tech', '--', 'Aadhar', 'Technology']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['demon', '--', 'note', 'ban']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['tech', '--', 'technologies']
# ['farmers', '--', 'crop', 'loan']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'crop', 'insurance']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'kisan']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'science']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'loan', 'waivers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhar']
# ['tech', '--', 'Technical']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'digital', 'payment']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmer', 'loan']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'tech']
# ['farmers', '--', 'kisan']
# ['tech', '--', 'Software']
# ['aadhar', '--', 'UIDAI']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'scientific']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'loan', 'waiver']
# ['gst', '--', 'tax', 'reform']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'ATMs']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['aadhar', '--', 'Aadhar']
# ['aadhar', '--', 'Aadhaar']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['farmers', '--', 'farmers']
# ['demon', 'farmers', '--', 'demonetisation', 'farmers']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technological']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'gst']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'farmer', 'suicides']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Digital', 'India']
# ['demon', '--', 'cash', 'crunch']
# ['gst', '--', 'taxpayers']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'gst']
# ['tech', '--', 'Software']
# ['farmers', '--', 'agricultural']
# ['tech', '--', 'Technical']
# ['aadhar', '--', 'UIDAI']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'startup']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'fake', 'currency']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'loan', 'waiver']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'cash', 'transaction']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'agriculture']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'excise', 'duty']
# ['tech', '--', 'scientific']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Engineering']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'Technology']
# ['gst', '--', 'SGST']
# ['demon', '--', 'Rs', '500', 'notes']
# ['tech', '--', 'Software']
# ['demon', '--', 'digital', 'payment']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['demon', '--', 'long', 'queue']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'drought']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'technologies']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'tech']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'Innovation']
# ['demon', '--', 'ATMs']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'crop', 'insurance']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'tech']
# ['aadhar', '--', 'Aadhar']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['gst', 'tech', '--', 'taxpayers', 'e-governance']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'black', 'money']
# ['demon', '--', 'digital', 'payment']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', 'tech', '--', 'cashless', 'economy', 'cashless']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'smart', 'city']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['tech', '--', 'tech']
# ['demon', '--', 'note', 'ban']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technical']
# ['aadhar', '--', 'Aadhaar']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['demon', 'gst', '--', 'demonetisation', 'gst']
# ['farmers', '--', 'farmer']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'GSTIN']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['farmers', 'tech', '--', 'agriculture', 'Technology']
# ['tech', '--', 'startup']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Software']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Software']
# ['tech', '--', 'smart', 'city']
# ['demon', 'tech', '--', 'demonetisation', 'cashless']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farm', 'loan']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'crop', 'loan']
# ['tech', '--', 'Technology']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'Technology']
# ['demon', '--', 'black', 'money']
# ['demon', 'tech', '--', 'cashless', 'economy', 'cashless']
# ['tech', '--', 'technologies']
# ['farmers', '--', 'agricultural']
# ['tech', '--', 'Privacy']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'startup']
# ['farmers', '--', 'farmers']
# ['farmers', 'tech', '--', 'agricultural', 'science']
# ['farmers', '--', 'farmers']
# ['aadhar', 'tech', '--', 'UIDAI', 'tech']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'entrepreneur']
# ['tech', '--', 'Technology']
# ['tech', '--', 'science']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'science']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['demon', 'gst', '--', 'note', 'ban', 'taxpayers']
# ['gst', '--', 'gst']
# ['tech', '--', 'e-governance']
# ['gst', '--', 'gst']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['demon', '--', 'cash', 'crunch']
# ['demon', '--', 'digital', 'transaction']
# ['gst', '--', 'SGST']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farm', 'loan']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'science']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'drought']
# ['tech', '--', 'entrepreneur']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'digital', 'payment']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmer']
# ['aadhar', 'tech', '--', 'UIDAI', 'tech']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'Swaminathan', 'Commission']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'entrepreneur']
# ['tech', '--', 'make', 'in', 'india']
# ['tech', '--', 'smart', 'city']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'Technological']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Innovation']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'Aadhar']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farm', 'loan']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'digital', 'transaction']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'drought']
# ['tech', '--', 'science']
# ['tech', '--', 'tech']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Innovation']
# ['tech', '--', 'Technical']
# ['demon', 'tech', '--', 'digital', 'transaction', 'cashless']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'loan', 'waiver']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmer']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Privacy']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'science']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'kisan']
# ['farmers', '--', 'farmer', 'suicides']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'Technological']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'waiver', 'scheme']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'black', 'money']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'Engineering']
# ['demon', 'tech', '--', 'cashless', 'transaction', 'cashless']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['tech', '--', 'entrepreneur']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'crop', 'losses']
# ['demon', '--', 'digital', 'payment']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer', 'suicides']
# ['demon', '--', 'digital', 'payment']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'technologies']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'loan', 'waiver']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'excise', 'duty']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'crop', 'losses']
# ['farmers', '--', 'farm', 'loan']
# ['aadhar', 'demon', '--', 'Aadhar', 'ATMs']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers', 'suicide']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'science']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'digital', 'transaction']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'crop', 'loss']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'loan', 'waiver']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Software']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'Artificial', 'Intelligence']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Unique', 'Identification']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'long', 'queue']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Innovation']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'entrepreneur']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', 'tech', '--', 'farmers', 'scientific']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'Technology']
# ['tech', '--', 'startup']
# ['demon', '--', 'Rs', '500', 'notes']
# ['tech', '--', 'cashless']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Innovation']
# ['tech', '--', 'e-governance']
# ['farmers', '--', 'farmers']
# ['farmers', 'gst', '--', 'farmers', 'gst']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'digital', 'payment']
# ['demon', '--', 'digital', 'payment']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['demon', 'tech', '--', 'demonetisation', 'cashless']
# ['tech', '--', 'Technology']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farm', 'loan']
# ['tech', '--', 'startup']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['farmers', 'tech', '--', 'agriculture', 'Technology']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'cash', 'crunch']
# ['farmers', '--', 'farmer', 'suicides']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'startup']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'digital', 'payment']
# ['aadhar', 'tech', '--', 'Aadhar', 'e-governance']
# ['farmers', '--', 'loan', 'waiver']
# ['farmers', '--', 'farmer', 'suicides']
# ['tech', '--', 'science']
# ['tech', '--', 'Software']
# ['farmers', '--', 'agricultural']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'agrarian', 'crisis']
# ['farmers', '--', 'agricultural']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['tech', '--', 'Engineering']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'drought']
# ['demon', 'farmers', '--', 'demonetisation', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gabbar', 'singh', 'tax']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'gst']
# ['aadhar', 'farmers', '--', 'Aadhaar', 'farmers']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'gst']
# ['demon', 'farmers', '--', 'black', 'money', 'farmers']
# ['farmers', '--', 'farm', 'loan']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhar']
# ['aadhar', '--', 'UID']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farm', 'loan']
# ['aadhar', '--', 'UIDAI']
# ['farmers', 'tech', '--', 'agriculture', 'science']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'e-governance']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agricultural']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhar']
# ['tech', '--', 'Technology']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers', 'suicide']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'Technical']
# ['gst', '--', 'gst']
# ['gst', 'tech', '--', 'Goods', 'and', 'Services', 'Tax', 'Technology']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'Innovation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'crop', 'loan']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'science']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'Engineering']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmers']
# ['demon', 'tech', '--', 'cashless', 'transaction', 'cashless']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'note', 'ban']
# ['tech', '--', 'Technological']
# ['tech', '--', 'Software']
# ['tech', '--', 'Engineering']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farm', 'loan']
# ['tech', '--', 'scientific']
# ['tech', '--', 'make', 'in', 'india']
# ['demon', '--', 'note', 'ban']
# ['farmers', '--', 'agriculture']
# ['demon', 'gst', '--', 'demonetisation', 'gst']
# ['gst', '--', 'gst']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['demon', 'gst', '--', 'black', 'money', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'loan', 'waiver']
# ['aadhar', '--', 'Aadhar']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['tech', '--', 'tech']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['tech', '--', 'smart', 'city']
# ['farmers', '--', 'kisan']
# ['gst', '--', 'gst']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'GSP']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'note', 'ban']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Privacy']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'Technology']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['demon', 'gst', '--', 'demonetisation', 'gst']
# ['demon', 'farmers', '--', 'note', 'ban', 'farmers']
# ['tech', '--', 'startup']
# ['tech', '--', 'Innovation']
# ['tech', '--', 'Innovation']
# ['gst', '--', 'gst']
# ['demon', '--', 'note', 'ban']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'UIDAI']
# ['demon', 'farmers', '--', 'demonetisation', 'agrarian', 'crisis']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['aadhar', '--', 'Aadhar']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farming', 'community']
# ['demon', '--', 'digital', 'payment']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'farming', 'community']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'loan', 'waivers']
# ['demon', '--', 'note', 'ban']
# ['tech', '--', 'Innovation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'ATMs']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'smart', 'city']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agricultural']
# ['aadhar', '--', 'UIDAI']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'drought']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'make', 'in', 'india']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', 'tech', '--', 'ATMs', 'cashless']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Artificial', 'Intelligence']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['tech', '--', 'science']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'UIDAI']
# ['tech', '--', 'science']
# ['farmers', '--', 'drought']
# ['tech', '--', 'startup']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Software']
# ['tech', '--', 'Technical']
# ['demon', '--', 'digital', 'payment']
# ['tech', '--', 'smart', 'city']
# ['gst', '--', 'gabbar', 'singh', 'tax']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhar']
# ['farmers', '--', 'crop', 'loan']
# ['tech', '--', 'Engineering']
# ['farmers', '--', 'farmer']
# ...
# ['demon', 'tech', '--', 'cashless', 'transaction', 'cashless']
# ['tech', '--', 'entrepreneur']
# ['gst', '--', 'taxpayers']
# ['farmers', 'tech', '--', 'agricultural', 'Engineering']
# ['tech', '--', 'Technology']
# ['tech', '--', 'startup']
# ['aadhar', '--', 'UIDAI']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Unique', 'Identification']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'Technical']
# ['aadhar', 'tech', '--', 'UIDAI', 'Technology']
# ['gst', '--', 'tax', 'reform']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmer']
# ['tech', '--', 'Innovation']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'tech']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'make', 'in', 'india']
# ['tech', '--', 'Technical']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'drought']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'kisan']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['tech', '--', 'Technological']
# ['farmers', '--', 'crop', 'loan']
# ['farmers', 'tech', '--', 'farmers', 'Technology']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'scientific']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technological']
# ['demon', 'gst', '--', 'black', 'money', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['tech', '--', 'smart', 'city']
# ['farmers', '--', 'loan', 'waivers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farming', 'community']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['gst', '--', 'gst']
# ['farmers', '--', 'crop', 'loan']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'loan', 'waiver']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'tech']
# ['tech', '--', 'Technology']
# ['aadhar', '--', 'unique', 'identity', 'number']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'loan', 'waiver']
# ['farmers', '--', 'loan', 'waivers']
# ['aadhar', '--', 'Aadhar']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhaar']
# ['demon', 'farmers', '--', 'demonetisation', 'agricultural']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'drought']
# ['tech', '--', 'Technology']
# ['tech', '--', 'science']
# ['aadhar', '--', 'UIDAI']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'digital', 'transaction']
# ['aadhar', '--', 'Aadhar']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['tech', '--', 'tech']
# ['demon', '--', 'pos', 'machine']
# ['farmers', '--', 'farm', 'loan']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'loan', 'waiver']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'scientific']
# ['tech', '--', 'cashless']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'scientific']
# ['demon', '--', 'cash', 'transaction']
# ['farmers', '--', 'loan', 'waiver']
# ['demon', '--', 'digital', 'transaction']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'crop-insurance']
# ['tech', '--', 'Technical']
# ['tech', '--', 'entrepreneur']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer']
# ['demon', 'gst', '--', 'demonetisation', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'digital', 'transaction']
# ['tech', '--', 'Innovation']
# ['farmers', '--', 'debt', 'waiver']
# ['demon', '--', 'black', 'money']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'UIDAI']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'Technology']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'UID']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'taxpayers']
# ['farmers', '--', 'farming', 'community']
# ['farmers', '--', 'loan', 'waiver']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Technology']
# ['tech', '--', 'science']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'digital', 'payment']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agrarian', 'crisis']
# ['gst', '--', 'gst']
# ['farmers', '--', 'kisan']
# ['tech', '--', 'Innovation']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'excise', 'duty']
# ['aadhar', '--', 'UIDAI']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'UIDAI']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'Aadhar']
# ['gst', '--', 'excise', 'duty']
# ['aadhar', 'tech', '--', 'UID', 'Privacy']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'crop', 'loan']
# ['tech', '--', 'scientific']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Technology']
# ['demon', 'gst', '--', 'demonetisation', 'gst']
# ['tech', '--', 'science']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['demon', '--', 'note', 'ban']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'UIDAI']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Software']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'drought']
# ['aadhar', '--', 'UIDAI']
# ['demon', 'gst', '--', 'demonetisation', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['farmers', '--', 'agrarian']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'long', 'queue']
# ['aadhar', '--', 'Aadhaar']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'loan', 'waivers']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technical']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['aadhar', '--', 'Enrolment', 'Number']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Innovation']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Engineering']
# ['farmers', '--', 'farmer', 'suicides']
# ['farmers', '--', 'crop', 'loan']
# ['farmers', '--', 'farm', 'loan']
# ['demon', 'farmers', '--', 'cash', 'transaction', 'agriculture']
# ['farmers', '--', 'farmer', 'suicides']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'drought']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'Innovation']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'kisan']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agricultural']
# ['farmers', '--', 'farming', 'community']
# ['aadhar', '--', 'Aadhar']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['farmers', '--', 'drought']
# ['demon', '--', 'demonetisation']
# ['aadhar', '--', 'UIDAI']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'agriculture']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'farmer']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'ATMs']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'entrepreneur']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'loan', 'waiver']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Engineering']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'Technical']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'loan', 'waiver']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'make', 'in', 'india']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'taxpayers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'agricultural']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Innovation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['tech', '--', 'Engineering']
# ['farmers', '--', 'farmers']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmers', 'suicide']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'taxpayers']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'UID']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'black', 'money']
# ['aadhar', '--', 'Aadhar']
# ['tech', '--', 'Technology']
# ['aadhar', '--', 'Unique', 'Identification']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'agriculture']
# ['demon', 'gst', '--', 'demonetisation', 'gst']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technical']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['demon', 'farmers', '--', 'black', 'money', 'farmer']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'black', 'money']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['demon', '--', 'cash', 'transaction']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'crop', 'loan']
# ['tech', '--', 'startup']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['demon', '--', 'black', 'money']
# ['farmers', '--', 'loan', 'waiver']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['demon', '--', 'black', 'money']
# ['tech', '--', 'Technical']
# ['aadhar', '--', 'Aadhaar']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'farmer']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'kisan']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'science']
# ['tech', '--', 'entrepreneur']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'gst']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmer', 'loan']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['farmers', '--', 'drought']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'kisan']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'demonetisation']
# ['demon', 'tech', '--', 'cashless', 'transaction', 'cashless']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'ATMs']
# ['tech', '--', 'Technology']
# ['demon', '--', 'digital', 'payment']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['tech', '--', 'e-governance']
# ['tech', '--', 'Technical']
# ['tech', '--', 'Technical']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'science']
# ['tech', '--', 'Technical']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['tech', '--', 'entrepreneur']
# ['tech', '--', 'Technology']
# ['tech', '--', 'Technology']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farming', 'community']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'debt', 'waiver']
# ['farmers', '--', 'drought']
# ['demon', '--', 'demonetisation']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['demon', 'tech', '--', 'cashless', 'economy', 'cashless']
# ['farmers', 'tech', '--', 'agricultural', 'science']
# ['farmers', '--', 'agricultural']
# ['farmers', '--', 'farmer']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['demon', '--', 'note', 'ban']
# ['farmers', '--', 'crop', 'loan']
# ['aadhar', '--', 'UIDAI']
# ['farmers', '--', 'loan', 'waiver']
# ['tech', '--', 'Technological']
# ['farmers', '--', 'crop', 'loan']
# ['farmers', '--', 'agricultural']
# ['aadhar', '--', 'Aadhaar']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmer', 'suicides']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['farmers', '--', 'kisan']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['tech', '--', 'science']
# ['farmers', '--', 'debt', 'waiver']
# ['gst', '--', 'GSTR']
# ['aadhar', '--', 'Aadhaar']
# ['tech', '--', 'Technology']
# ['farmers', 'tech', '--', 'farmers', 'Technology']
# ['tech', '--', 'tech']
# ['tech', '--', 'make', 'in', 'india']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'science']
# ['demon', '--', 'demonetisation']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'agriculture']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'denomination', 'note']
# ['demon', '--', 'digital', 'payment']
# ['gst', '--', 'gst']
# ['aadhar', '--', 'UIDAI']
# ['gst', '--', 'Goods', 'and', 'Services', 'Tax']
# ['gst', '--', 'gst']
# ['tech', '--', 'science']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'waiver', 'scheme']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'fake', 'currency']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['tech', '--', 'Technology']
# ['gst', '--', 'gst']
# ['tech', '--', 'Technology']
# ['demon', 'gst', '--', 'demonetisation', 'gst']
# ['gst', '--', 'gst']
# ['farmers', '--', 'farmers']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'demonetisation']
# ['demon', '--', 'Rs', '1,000', 'notes']
# ['tech', '--', 'make', 'in', 'india']
# ['farmers', '--', 'drought']
# ['farmers', '--', 'drought']
# ['tech', '--', 'science']
# ['farmers', '--', 'agriculture']
# ['gst', '--', 'gst']
# ['farmers', '--', 'agriculture']
# ['demon', '--', 'demonetisation']
# ['tech', '--', 'Innovation']
# ['farmers', '--', 'farmers']
# ['demon', '--', 'unaccounted', 'money']
# ['farmers', '--', 'agricultural']
# ['demon', '--', 'black', 'money']
# 334 0 56 0

# %%
file_a = open(base + 'aadhar_all.txt','w')
file_d = open(base + 'digital_india_all.txt','w')
file_c = open(base + 'cashless_all.txt','w')
file_e = open(base + 'egov_all.txt','w')
for line in aadhar_lines:
    file_a.write(line)
for line in digital_india_lines:
    file_d.write(line)
for line in cashless_lines:
    file_c.write(line)
for line in egov_lines:
    file_e.write(line)
file_a.close()
file_d.close()
file_c.close()
file_e.close()

# %% [markdown]
# #### Policy filtering for ICTD policies

# %%
aadhar_lines = []
demon_lines = []
farmers_lines = []
gst_lines = []
tech_lines = []
with open(base + "refined-all-by-stmnts.txt",'r') as file_s, open(base + "out-all-by-stmnts.txt",'r') as file_o: 
    for x, y in zip(file_s, file_o):
        y = y.strip().split(" ")
        if len(y)>1:
            print(y)
        for policy in y:
            if policy=="aadhar":
                aadhar_lines.append(x)
            if policy=="farmers":
                farmers_lines.append(x)
            if policy=="demon":
                demon_lines.append(x)
            if policy=="tech":
                tech_lines.append(x)
            if policy=="gst":
                gst_lines.append(x)
aadhar_lines = list(set(aadhar_lines))
farmers_lines = list(set(farmers_lines))
demon_lines = list(set(demon_lines))
tech_lines = list(set(tech_lines))
gst_lines = list(set(gst_lines))
print(len(aadhar_lines), len(farmers_lines), len(demon_lines), len(tech_lines), len(gst_lines))

# %%
file_a = open(base + 'aadhar_all.txt','w')
file_d = open(base + 'demon_all.txt','w')
file_f = open(base + 'farmers_all.txt','w')
file_g = open(base + 'gst_all.txt','w')
file_t = open(base + 'tech_all.txt','w')
for line in aadhar_lines:
    file_a.write(line)
for line in demon_lines:
    file_d.write(line)
for line in tech_lines:
    file_t.write(line)
for line in gst_lines:
    file_g.write(line)
for line in farmers_lines:
    file_f.write(line)
file_a.close()
file_d.close()
file_f.close()
file_g.close()
file_t.close()

# %% [markdown]
# ### Relevance Check

# %% [markdown]
# #### Using pobj

# %%
idx = 5 # this indicates policy -- 0 -> aadhar, 1 -> demon, 2 -> farmers, 3 -> gst, 4 -> tech

# %%
nlp = en_core_web_sm.load()
nlp.add_pipe(merge_entities)

def is_relevant(sent, keywords):
    doc = nlp(sent)
    for chunk in (doc.noun_chunks):
        if chunk.root.dep_!='nsubj' and chunk.root.dep_!='nsubjpass':
            continue
        for word in keywords:
            if is_phrase_in(word, chunk.text):
                return True
    return False

# %%
def process2(keywords):
    keywords_small = [x.lower() for x in keywords]
    keywords_big = [x.upper() for x in keywords]
    keywords_hypen = [x.replace(" ", "-") for x in keywords]
    total_keywords = list(set(keywords + keywords_hypen + keywords_small + keywords_big))
    return total_keywords

# %%
files = ['aadhar_all.txt', 'demon_all.txt', 'farmers_all.txt', 'gst_all.txt','tech_all.txt']
f = open(base + files[idx], 'r+')
dicti = {files[0]:keywords_aadhar, 
         files[1]:keywords_demon, 
         files[2]:keywords_farmers, 
         files[3]:keywords_gst,
         files[4]:keywords_tech}
print(files[idx])
rel_count = 0
total_count = 0
total_keywords = process2(dicti[files[idx]])
print(total_keywords)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-4c4f13b02b20> in <module>
#       1 files = ['aadhar_all.txt', 'demon_all.txt', 'farmers_all.txt', 'gst_all.txt','tech_all.txt']
# ----> 2 f = open(base + files[idx], 'r+')
#       3 dicti = {files[0]:keywords_aadhar,
#       4          files[1]:keywords_demon,
#       5          files[2]:keywords_farmers,
#
# IndexError: list index out of range

# %%
f2 = open(base + 'pobj_relevant_' + files[idx], 'w+')
for line in f:
    total_count += 1
    if(is_relevant_by_pobj(line.strip(), total_keywords)):
        rel_count += 1
        f2.write(line)
f2.close()
print(rel_count, total_count)

# %% [markdown]
# #### Using Supervised Models

# %%
idx = 3 # this indicates policy -- 0 -> aadhar, 1 -> demon, 2 -> farmers, 3 -> gst, 4 -> tech

# %%
def read_into_string(filename):
    text_file = open(filename, 'r')
    lines = []
    for line in text_file:
        sentence = line.strip().lower()
        if(len(sentence) > 0):
            lines.append(line)
    text_file.close()
    return lines
print(files[idx])
dataset = read_into_string(base + files[idx])

# %%
def supervised_results(X_test, text_clf):
    predicted = text_clf.predict(X_test)
    f = open(base + 'supervised_relevant_' + files[idx], 'w+')
    for sentence, prediction in zip(X_test, predicted):
        if(prediction == 1):
            f.write(sentence)
    f.close()
    print('relevant statements: {}, Total statements: {}'.format(sum(predicted), len(X_test))) # relevant-1, non-relevant-0

# %%
supervised_results(dataset, pkl.load(open(base + files[idx][:-8] + '-model.pkl', 'rb')))

# %%
policies = ['aadhar', 'demon', 'farmers', 'gst', 'tech']
